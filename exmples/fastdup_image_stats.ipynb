# %% [markdown]
# <a href="https://colab.research.google.com/github/visualdatabase/fastdup/blob/main/exmples/fastdup_image_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fastdup tutorial:
# In this tutorial we learn how to look at different image statistics like bluriness, darkness and image size using fastdup

# %% [markdown]
# ## Install fastdup

# %%
pip install -U fastdup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fastdup
#   Downloading fastdup-0.122-cp37-cp37m-manylinux_2_27_x86_64.whl (38.8 MB)
#      |████████████████████████████████| 38.8 MB 1.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fastdup) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from fastdup) (3.13)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fastdup) (1.3.5)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from fastdup) (4.6.0.66)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from fastdup) (4.64.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fastdup) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fastdup) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->fastdup) (1.15.0)
# Installing collected packages: fastdup
# Successfully installed fastdup-0.122

# %% [markdown]
# ## Download a sample dataset

# %%
# !gdown 1MPq6dSE5rGHCuNiW-4cAJL37JxJWYy_p
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1MPq6dSE5rGHCuNiW-4cAJL37JxJWYy_p
# To: /content/hamburger.zip
# 100% 50.0M/50.0M [00:00<00:00, 244MB/s]

# %%
# !unzip -qq hamburger.zip

# %% [markdown]
# ## Run fastdup to compute image feature vectors and image statistics

# %%
import fastdup
fastdup.run('food-101/', work_dir='out')
# Out:
# FastDup Software, (C) copyright 2022 Dr. Amir Alush and Dr. Danny Bickson.
# On Jupyter notebook running on large datasets, there may be delay getting the console output. We recommend running using python shell.
# 0

# %% [markdown]
# Full documentation is found [here](https://visualdatabase.github.io/fastdup/).

# %% [markdown]
# ## Find the most blurry images

# %%
import fastdup
from IPython.display import HTML
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='blur',num_images=5)
HTML('./blur.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 122.06it/s]
# Storedblur statistics view in  ./blur.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - blur Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>blur</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>709</th>
#       <td>64.114677</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3702789.jpg</td>
#     </tr>
#     <tr>
#       <th>819</th>
#       <td>102.108147</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/5052.jpg</td>
#     </tr>
#     <tr>
#       <th>980</th>
#       <td>134.564697</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/922386.jpg</td>
#     </tr>
#     <tr>
#       <th>456</th>
#       <td>151.301346</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2710786.jpg</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>153.413406</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1086335.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %% [markdown]
# ## Find the sharpest images

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='blur',descending=True, num_images=5)
HTML('./blur.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 99.68it/s]
# Storedblur statistics view in  ./blur.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - blur Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>blur</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>35</th>
#       <td>9905.028320</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1101890.jpg</td>
#     </tr>
#     <tr>
#       <th>743</th>
#       <td>9649.861328</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3805259.jpg</td>
#     </tr>
#     <tr>
#       <th>514</th>
#       <td>9632.191406</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2935045.jpg</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>8998.842773</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1144233.jpg</td>
#     </tr>
#     <tr>
#       <th>555</th>
#       <td>7918.315430</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3101158.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %% [markdown]
# ## Find the smallest images

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='size',descending=False, num_images=5)
HTML('./size.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 130.20it/s]
# Storedsize statistics view in  ./size.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - size Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>size</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>208</th>
#       <td>135680</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1768219.jpg</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>146432</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1210060.jpg</td>
#     </tr>
#     <tr>
#       <th>955</th>
#       <td>146944</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/840018.jpg</td>
#     </tr>
#     <tr>
#       <th>786</th>
#       <td>146944</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/419342.jpg</td>
#     </tr>
#     <tr>
#       <th>691</th>
#       <td>147456</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3643079.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %% [markdown]
# ## Find the largest images

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='size',descending=True, num_images=5)
HTML('./size.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 82.88it/s]
# Storedsize statistics view in  ./size.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - size Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>size</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>500</th>
#       <td>262144</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2894838.jpg</td>
#     </tr>
#     <tr>
#       <th>426</th>
#       <td>262144</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2573191.jpg</td>
#     </tr>
#     <tr>
#       <th>757</th>
#       <td>262144</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3866906.jpg</td>
#     </tr>
#     <tr>
#       <th>756</th>
#       <td>262144</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3866252.jpg</td>
#     </tr>
#     <tr>
#       <th>430</th>
#       <td>262144</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2588852.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %% [markdown]
# ## Find the darkest images

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='mean',descending=False, num_images=5)
HTML('./mean.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 122.33it/s]
# Storedmean statistics view in  ./mean.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - mean Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mean</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62</th>
#       <td>27.801983</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/120612.jpg</td>
#     </tr>
#     <tr>
#       <th>779</th>
#       <td>35.449856</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/40675.jpg</td>
#     </tr>
#     <tr>
#       <th>595</th>
#       <td>38.664860</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3268517.jpg</td>
#     </tr>
#     <tr>
#       <th>635</th>
#       <td>38.856247</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3413347.jpg</td>
#     </tr>
#     <tr>
#       <th>733</th>
#       <td>39.266655</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3769905.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %% [markdown]
# ## Find the brightest images

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='mean',descending=True, num_images=5)
HTML('./mean.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 130.38it/s]
# Storedmean statistics view in  ./mean.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - mean Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mean</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>162</th>
#       <td>225.706345</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1585333.jpg</td>
#     </tr>
#     <tr>
#       <th>737</th>
#       <td>220.730469</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3783650.jpg</td>
#     </tr>
#     <tr>
#       <th>680</th>
#       <td>220.730469</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3578279.jpg</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>201.403366</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/1192222.jpg</td>
#     </tr>
#     <tr>
#       <th>486</th>
#       <td>177.674042</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2836127.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>

# %%
fastdup.create_stats_gallery('out/atrain_stats.csv','.',max_width=400,metric='unique',descending=True, num_images=5)
HTML('./unique.html')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 72.60it/s]
# Storedunique statistics view in  ./unique.html
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - unique Image Report </h2></center>
# <table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#       <th>Image</th>
#       <th>filename</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>794</th>
#       <td>15867</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/440931.jpg</td>
#     </tr>
#     <tr>
#       <th>631</th>
#       <td>14810</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/3406531.jpg</td>
#     </tr>
#     <tr>
#       <th>386</th>
#       <td>14482</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2411538.jpg</td>
#     </tr>
#     <tr>
#       <th>441</th>
#       <td>14270</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2623364.jpg</td>
#     </tr>
#     <tr>
#       <th>498</th>
#       <td>14163</td>
#       <td><img src="data:image/jpeg;base64,..." width="400"></td>
#       <td>food-101/images/hamburger/2884546.jpg</td>
#     </tr>
#   </tbody>
# </table> </body>
#         </html>
