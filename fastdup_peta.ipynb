# %% [markdown]
# <a href="https://colab.research.google.com/github/visualdatabase/fastdup/blob/main/fastdup_peta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install fastdup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastdup in /usr/local/lib/python3.7/dist-packages (0.142)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from fastdup) (4.6.0.66)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from fastdup) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from fastdup) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fastdup) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fastdup) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fastdup) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fastdup) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->fastdup) (1.15.0)

# %% [markdown]
# # Download the PETA dataset

# %%
# PETA dataset from: http://mmlab.ie.cuhk.edu.hk/projects/PETA.html
# !gdown 1tH5g0fs-VBrGAY2jru5hZz5q1jkHMbK_
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1tH5g0fs-VBrGAY2jru5hZz5q1jkHMbK_
# To: /content/PETA.zip
# 100% 236M/236M [00:00<00:00, 242MB/s]

# %%
# !unzip -qq /content/PETA.zip -d /content/
# Out:
# replace /content/ReadMe.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# !mv '/content/PETA dataset/' /content/peta
# Out:
# mv: cannot stat '/content/PETA dataset/': No such file or directory

# %%
import fastdup

# %%
import os
files = os.listdir('/content/peta')
files = [f for f in files if not f.endswith('txt') and not 'dataset' in f]

# %%
import pandas as pd
def get_label_list(fname):
    with open('/content/peta/' + fname + '/archive/Label.txt') as f:
        lines = []
        index = []
        filename = []
        line = f.readline().replace('\n','')
        lines.append(line.split(' ')[1:])
        index.append(line.split(' ')[0])
        filename.append(fname)
        while (line != ''):
            line = f.readline().replace('\n','')
            if len(line):
                lines.append(line.split(' ')[1:])
                index.append(line.split(' ')[0])
                filename.append(fname)

    return pd.DataFrame({'index':index, 'labels':lines, 'file':filename})

# %%
labels = pd.DataFrame()
for i in files:
    ret = get_label_list(i)
    labels = labels.append(ret)

# %%
labels.head()
# Out:
#   index  \
# 0  0709
# 1  0059
# 2  0057
# 3  0058
# 4  0055
#
#                                                                                                                                                                                                                                                                        labels  \
# 0                          [upperBodyBlack, lowerBodyBlue, hairBrown, footwearBlack, lowerBodyCasual, lowerBodyJeans, personalLess45, personalMale, upperBodyFormal, upperBodyLongSleeve, upperBodySuit, hairShort, footwearLeatherShoes, carryingSuitcase, accessoryNothing]
# 1  [upperBodyBlack, lowerBodyBlack, hairBrown, footwearBlack, lowerBodyFormal, lowerBodyTrousers, personalFemale, personalLess45, upperBodyFormal, upperBodyLongSleeve, upperBodyOther, hairLong, footwearLeatherShoes, carryingOther, carryingPlasticBags, accessoryNothing]
# 2                [upperBodyWhite, lowerBodyBlue, hairGrey, footwearBlack, lowerBodyCasual, lowerBodyTrousers, personalFemale, personalLess60, upperBodyCasual, upperBodyShortSleeve, upperBodyTshirt, hairShort, footwearLeatherShoes, carryingBackpack, accessorySunglasses]
# 3                        [upperBodyGrey, lowerBodyGrey, hairBlack, footwearBlack, lowerBodyFormal, lowerBodyTrousers, personalLess60, personalMale, upperBodyFormal, upperBodyLongSleeve, upperBodySuit, hairShort, footwearLeatherShoes, carryingBackpack, accessoryNothing]
# 4                       [upperBodyBlack, lowerBodyBlack, hairBlack, footwearBlack, lowerBodyCasual, lowerBodyTrousers, personalFemale, personalLess45, upperBodyCasual, upperBodyLongSleeve, upperBodyOther, hairLong, footwearLeatherShoes, carryingOther, accessoryNothing]
#
#    file
# 0  PRID
# 1  PRID
# 2  PRID
# 3  PRID
# 4  PRID

# %%
def get_label(fname):
    path = fname.split('/')[-3]
    basename = os.path.basename(fname)
    index = basename.split('_')[0]
    #print('index is', index, 'path', path)
    pot = labels[labels['file'] == path]
    pot = pot[pot['index'] == index]
    #print(pot.head())
    if len(pot):
        #print(pot['labels'].values[0])
        return pot['labels'].values[0]
    else:
        return None

# %%
# %pip install wurlitzer
# %load_ext wurlitzer
# !rm -fr out_peta
fastdup.run("/content/peta/", work_dir='out_peta', turi_param='ccthreshold=0.95')

# %%
fastdup.create_components_gallery('out_peta', '.', get_label_func=get_label, num_images=5)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 27.30it/s]
# Finished OK. Components are stored as image files ./components_index_id.jpg
# Stored components visual view in  ./components.html

# %%
from IPython.display import HTML
HTML('./components.html')
# Out:
#
# <html> <head> <style>
# html{
# font-family: Tahoma, Geneva, sans-serif;
# }
# table {
# border-collapse: collapse;
# font-family: Tahoma, Geneva, sans-serif;
# }
# table, th, tr, td
# {
# border: 0px !important;
# border-collapse: collapse !important;
# border:none !important;
# outline:none !important;
# text-align: left;
# max-width: 1200px !important;
# }
# table td {
# padding: 15px;
# }
# table thead td {
# background-color: #54585d;
# color: #ffffff;
# font-weight: bold;
# font-size: 13px;
# }
# table tbody td {
# color: #636363;
# }
# table tbody tr
# {
# background-color: #f9fafb;
# }
#
# table tbody tr:nth-child(odd) {
# background-color: #ffffff;
# }
#     </style> </head> <body> <center><h2> Fastdup Tool - Components Report </h2></center><br><left><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th>stats</th>      <th>image</th>    </tr>  </thead>  <tbody>    <tr>      <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>len</th>    </tr>  </thead>  <tbody>    <tr>      <th>count</th>      <td>17996.000000</td>    </tr>    <tr>      <th>mean</th>      <td>1.055790</td>    </tr>    <tr>      <th>std</th>      <td>0.757953</td>    </tr>    <tr>      <th>min</th>      <td>1.000000</td>    </tr>    <tr>      <th>25%</th>      <td>1.000000</td>    </tr>    <tr>      <th>50%</th>      <td>1.000000</td>    </tr>    <tr>      <th>75%</th>      <td>1.000000</td>    </tr>    <tr>      <th>max</th>      <td>45.000000</td>    </tr>  </tbody></table></td>      <td><img src="data:image/jpeg;base64,..."></td>    </tr>  </tbody></table></left><br><table border="1" class="dataframe wide">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>info</th>
#       <th>image</th>
#       <th>labels</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><table border="1" class="dataframe">  <tbody>    <tr>      <th>component</th>      <td>1420</td>    </tr>    <tr>      <th>num_images</th>      <td>45</td>    </tr>  </tbody></table></td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>counts</th>    </tr>  </thead>  <tbody>    <tr>      <th>accessoryNothing</th>      <td>45</td>    </tr>    <tr>      <th>carryingMessengerBag</th>      <td>45</td>    </tr>    <tr>      <th>footwearBlack</th>      <td>45</td>    </tr>    <tr>      <th>footwearLeatherShoes</th>      <td>45</td>    </tr>    <tr>      <th>hairBlack</th>      <td>45</td>    </tr>    <tr>      <th>hairShort</th>      <td>45</td>    </tr>    <tr>      <th>lowerBodyBlack</th>      <td>45</td>    </tr>    <tr>      <th>lowerBodyCasual</th>      <td>45</td>    </tr>    <tr>      <th>lowerBodyTrousers</th>      <td>45</td>    </tr>    <tr>      <th>personalLess45</th>      <td>45</td>    </tr>    <tr>      <th>personalMale</th>      <td>45</td>    </tr>    <tr>      <th>upperBodyCasual</th>      <td>45</td>    </tr>    <tr>      <th>upperBodyLongSleeve</th>      <td>45</td>    </tr>    <tr>      <th>upperBodyOther</th>      <td>45</td>    </tr>    <tr>      <th>upperBodyWhite</th>      <td>45</td>    </tr>  </tbody></table></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><table border="1" class="dataframe">  <tbody>    <tr>      <th>component</th>      <td>680</td>    </tr>    <tr>      <th>num_images</th>      <td>39</td>    </tr>  </tbody></table></td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>counts</th>    </tr>  </thead>  <tbody>    <tr>      <th>accessoryNothing</th>      <td>39</td>    </tr>    <tr>      <th>carryingBackpack</th>      <td>39</td>    </tr>    <tr>      <th>footwearBlack</th>      <td>39</td>    </tr>    <tr>      <th>footwearShoes</th>      <td>39</td>    </tr>    <tr>      <th>hairBrown</th>      <td>39</td>    </tr>    <tr>      <th>hairShort</th>      <td>39</td>    </tr>    <tr>      <th>lowerBodyCasual</th>      <td>39</td>    </tr>    <tr>      <th>lowerBodyGrey</th>      <td>39</td>    </tr>    <tr>      <th>lowerBodyTrousers</th>      <td>39</td>    </tr>    <tr>      <th>personalLess30</th>      <td>39</td>    </tr>    <tr>      <th>personalMale</th>      <td>39</td>    </tr>    <tr>      <th>upperBodyCasual</th>      <td>39</td>    </tr>    <tr>      <th>upperBodyLongSleeve</th>      <td>39</td>    </tr>    <tr>      <th>upperBodyWhite</th>      <td>39</td>    </tr>  </tbody></table></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><table border="1" class="dataframe">  <tbody>    <tr>      <th>component</th>      <td>3727</td>    </tr>    <tr>      <th>num_images</th>      <td>31</td>    </tr>  </tbody></table></td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>counts</th>    </tr>  </thead>  <tbody>    <tr>      <th>accessoryNothing</th>      <td>31</td>    </tr>    <tr>      <th>carryingMessengerBag</th>      <td>31</td>    </tr>    <tr>      <th>footwearBlack</th>      <td>31</td>    </tr>    <tr>      <th>footwearShoes</th>      <td>31</td>    </tr>    <tr>      <th>hairBrown</th>      <td>31</td>    </tr>    <tr>      <th>hairShort</th>      <td>31</td>    </tr>    <tr>      <th>lowerBodyBlack</th>      <td>31</td>    </tr>    <tr>      <th>lowerBodyFormal</th>      <td>31</td>    </tr>    <tr>      <th>lowerBodyTrousers</th>      <td>31</td>    </tr>    <tr>      <th>personalFemale</th>      <td>31</td>    </tr>    <tr>      <th>personalLarger60</th>      <td>31</td>    </tr>    <tr>      <th>upperBodyFormal</th>      <td>31</td>    </tr>    <tr>      <th>upperBodyGrey</th>      <td>31</td>    </tr>    <tr>      <th>upperBodyLongSleeve</th>      <td>31</td>    </tr>    <tr>      <th>upperBodyOther</th>      <td>31</td>    </tr>  </tbody></table></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><table border="1" class="dataframe">  <tbody>    <tr>      <th>component</th>      <td>3044</td>    </tr>    <tr>      <th>num_images</th>      <td>30</td>    </tr>  </tbody></table></td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>counts</th>    </tr>  </thead>  <tbody>    <tr>      <th>accessoryNothing</th>      <td>30</td>    </tr>    <tr>      <th>carryingNothing</th>      <td>30</td>    </tr>    <tr>      <th>footwearBlack</th>      <td>30</td>    </tr>    <tr>      <th>footwearLeatherShoes</th>      <td>30</td>    </tr>    <tr>      <th>hairBrown</th>      <td>30</td>    </tr>    <tr>      <th>hairShort</th>      <td>30</td>    </tr>    <tr>      <th>lowerBodyBlack</th>      <td>30</td>    </tr>    <tr>      <th>lowerBodyFormal</th>      <td>30</td>    </tr>    <tr>      <th>lowerBodySuits</th>      <td>30</td>    </tr>    <tr>      <th>personalLess45</th>      <td>30</td>    </tr>    <tr>      <th>personalMale</th>      <td>30</td>    </tr>    <tr>      <th>upperBodyFormal</th>      <td>30</td>    </tr>    <tr>      <th>upperBodyGrey</th>      <td>30</td>    </tr>    <tr>      <th>upperBodyLongSleeve</th>      <td>30</td>    </tr>    <tr>      <th>upperBodySuit</th>      <td>30</td>    </tr>  </tbody></table></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><table border="1" class="dataframe">  <tbody>    <tr>      <th>component</th>      <td>6206</td>    </tr>    <tr>      <th>num_images</th>      <td>30</td>    </tr>  </tbody></table></td>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td><table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>counts</th>    </tr>  </thead>  <tbody>    <tr>      <th>accessoryMuffler</th>      <td>30</td>    </tr>    <tr>      <th>lowerBodyHotPants</th>      <td>30</td>
